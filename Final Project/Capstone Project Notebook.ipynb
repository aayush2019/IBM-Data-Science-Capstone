# %% [markdown]
# # Applied Capstone Project - The Battle of Neighborhoods in Toronto, Canada

# %% [markdown]
# ### Introduction
#
# Toronto is Canada&#39;s largest city and a world leader in such areas as business, finance, technology, entertainment and culture. Its large population of immigrants from all over the globe has also made Toronto one of the most multicultural cities in the world.
#
# Toronto has the largest Indo-Canadian population in Canada comprising of 10.4% (approx. 0.6 million people) Almost 51% of the entire Indo-Canadian community resides in the Greater Toronto Area. Most Indo-Canadians in the Toronto area live in Brampton, Markham, Scarborough, Etobicoke, and Mississauga. The Indo-Canadians in this region are mostly of Punjabi, Telugu, Tamil, Gujarati, Marathi, Malayalee and Goan origin. Canadian carrier Air Canada operates flights from Toronto Pearson International Airport back to India.
#
# Also, students of Indian origin make up over 35% of Ryerson University, 30% of York University, and 20% of the University of Toronto&#39;s student bodies, respectively.
#
# With its diverse culture, comes diverse food items. There are many restaurants in Toronto, each belonging to different categories like Indian, Chinese, French etc.
#
# So as part of this project, we will list and visualize all major parts of Toronto that has great Indian Restaurants.
#
# ### Data
#
# For this project we need the following data:
#
# - Toronto data that contains list Boroughs, Neighborhoods along with their latitude and longitude.
#   - Data source: [click here](https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M)
#   - Description: This webpage contains the required information. And we will scrape this data set to explore various neighborhoods of Toronto.
#
# - Indian Restaurants in each neighborhood of Toronto
#   - Data source: Foursquare API
#   - Description: By using this API we will get all the venues in each neighborhood. We can filter these venues to get only Indian Restaurants.
#   - We can then get the likes, ratings etc., to rank the restaurants.
#
# - GeoSpace data
#   - Data source: [click here](https://cocl.us/Geospatial_data)
#   - By using this data we draw boundaries and visualize venues on map.
#
# ### Approach
#
# - View the Toronto&#39;s city data from: [URL](https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M)
# - Using Web Scrapping technique, collect required data.
# - Using Foursquare API, we will find all venues for each neighborhood.
# - Filter out all venues that are Indian Restaurants.
# - Find rating, tips and like count for each Indian Restaurants using Foursquare API.
# - Using rating for each restaurant, we will sort that data.
# - Visualize the Ranking of neighborhoods using folium library(python)
#
# ### Questions that can be asked using the above-mentioned datasets
#
# - What is best location in Toronto for Indian Cuisine?
# - Which areas have potential Indian Restaurant Market?
# - Which all areas lack Indian Restaurants?
# - Which is the best place to stay if I prefer Indian Cuisine?
#
# ### Analysis:

# %% [markdown]
# # Installing Libraries

# %%
#pip install beautifulsoup4 # for webscrapping
#pip install lxml # Python library which allows easy handling of XML and HTML files
#pip install requests # for handling request to websites
print('Libraries Installed')
# Out:
# Libraries Installed

# %% [markdown]
# # Importing Libraries

# %%
from bs4 import BeautifulSoup as bs # for webscrapping
import requests # for handling request to websites
import pandas as pd # for data analysis and manipulation
import numpy as np #for mathematical computing
import matplotlib.pyplot as plt # for plotting
import seaborn as sns# for plotting
import folium # map rendering library
from folium import plugins # to group nearby locations
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
print('Go Ahead!')
# Out:
# Go Ahead!

# %% [markdown]
# # Loading Web Page

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = bs(page,'html.parser')
#print(soup.prettify()) #Uncomment to view the html content
print('Go Ahead!')
# Out:
# Go Ahead!

# %% [markdown]
# # Viewing Title of WebPage

# %%
match= soup.title.text
print('Title of Webpage is: {}'.format(match))
# Out:
# Title of Webpage is: List of postal codes of Canada: M - Wikipedia

# %% [markdown]
# # Viewing Required Data from WebPage

# %%
table_post = soup.find('table')
#print(table_post.prettify()) # Uncomment to view html content

# %% [markdown]
# # Extracting Data from WebPage and Transforming into DataFrame

# %%
table_post = soup.find('table') # Extracting the required table
fields = table_post.find_all('td') # All required values are at 'td'

postcode = [] #Empty list to be appended
borough = [] #Empty list to be appended
neighbourhood = [] #Empty list to be appended

for i in range(0, len(fields),3): # Range Intitalizing from 0 to len(fields) which is no of 'td'=540, and step size of 3, since there are 3 columns 
    postcode.append(fields[i].text.strip()) # field 0, it is post code
    borough.append(fields[i+1].text.strip()) # filed 1, it is borough
    neighbourhood.append(fields[i+2].text.strip()) # field 2, it is neighborhood
        
df = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()# since all are list, we have to transform it to columns
df.columns = ['Postcode', 'Borough', 'Neighborhood']
df.head()
# Out:
#   Postcode           Borough               Neighborhood
# 0      M1A      Not assigned
# 1      M2A      Not assigned
# 2      M3A        North York                  Parkwoods
# 3      M4A        North York           Victoria Village
# 4      M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# We can see that some Borough values have not been assigned, so we will make a Dataframe with assigned values only.

# %% [markdown]
# # DataFrame without Borough as Not Assigned

# %%
# only_boroughs = df[df['Borough'] == 'Not assigned'].reset_index() # This data will have Borough=Not Assigned, 77 entries
df_reqd_1 = df[df['Borough'] != 'Not assigned'].reset_index(drop=True) #`drop` parameter to avoid the old index being added as a column

df_reqd_1.head()
# Out:
#   Postcode           Borough                                 Neighborhood
# 0      M3A        North York                                    Parkwoods
# 1      M4A        North York                             Victoria Village
# 2      M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3      M6A        North York             Lawrence Manor, Lawrence Heights
# 4      M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# # Dimension of DataFrame

# %%
df_reqd_1.shape
# Out:
# (103, 3)

# %% [markdown]
# We have 103 values in our DataFrame.

# %% [markdown]
# # Loading GeoSpatial DataSet into DataFrame

# %%
geo_url = 'https://cocl.us/Geospatial_data' 
df_geo = pd.read_csv(geo_url)
df_geo.rename(columns={'Postal Code':'Postcode'}, inplace=True) #Renaming 'Postal Code' from GeoSpatial df to 'Postcode', same as df_reqd_1
df_geo.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %% [markdown]
# We have a list of Postcode along with their respective location coordinated.
# We will merge it with the previous DataFrame to form a new DataFrame.

# %% [markdown]
# # Merging DataFrame
# Check whether it has any null values.

# %%
df_reqd_2 = pd.merge(df_reqd_1,df_geo,on='Postcode')
print(df_reqd_2.isnull().sum())
df_reqd_2.head()
# Out:
# Postcode        0
# Borough         0
# Neighborhood    0
# Latitude        0
# Longitude       0
# dtype: int64
#   Postcode           Borough                                 Neighborhood  \
# 0      M3A        North York                                    Parkwoods
# 1      M4A        North York                             Victoria Village
# 2      M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3      M6A        North York             Lawrence Manor, Lawrence Heights
# 4      M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# We have a new DataFrame with no null values.

# %% [markdown]
# # Defining a Function to get the Lat-Lon values of a given address.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>toronto_explorer</em>

# %%
def geo_location(address):
    geolocator = Nominatim(user_agent="toronto_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude
    print('The geograpical coordinate of {} are {}, {}.'.format(address,latitude, longitude))

# %% [markdown]
# # Visualizing Map of Toronto

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=geo_location('Toronto'), zoom_start=10,tiles='https://api.mapbox.com/styles/v1/explorer020/cka9yy2dn14l51iptugr1shzf/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoiZXhwbG9yZXIwMjAiLCJhIjoiY2thOXhvYjdyMHJoYzJycDRlbmw3YTg3ZiJ9.T9QjJc87oYLSknnlBH21Tg',attr='XXX Mapbox Attribution') # calling the geo_location function by passing address as Toronto.

# add markers to map
for lat, lng, borough, neighborhood in zip(df_reqd_2['Latitude'], df_reqd_2['Longitude'], df_reqd_2['Borough'], df_reqd_2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='Green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Here we can see that there is 1 place which belongs to Mississauga but it is wrongly mentioned under the Toronto City.
# ### We will remove it and plot it again.

# %%
df_reqd_2=df_reqd_2[~df_reqd_2["Borough"].isin(['Mississauga'])] #dropping Mississauga
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=geo_location('Toronto'), zoom_start=11,tiles='https://api.mapbox.com/styles/v1/explorer020/cka9yy2dn14l51iptugr1shzf/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoiZXhwbG9yZXIwMjAiLCJhIjoiY2thOXhvYjdyMHJoYzJycDRlbmw3YTg3ZiJ9.T9QjJc87oYLSknnlBH21Tg',attr='XXX Mapbox Attribution')

# add markers to map
for lat, lng, borough, neighborhood in zip(df_reqd_2['Latitude'], df_reqd_2['Longitude'], df_reqd_2['Borough'], df_reqd_2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='Green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    

map_toronto.save('map_1.html')
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Loading Foursquare API for exploring location

# %%
CLIENT_ID = '########################################' # your Foursquare ID
CLIENT_SECRET = '########################################'  # your Foursquare Secret
VERSION = '20200126' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' , CLIENT_ID)
print('CLIENT_SECRET:',CLIENT_SECRET)

# %% [markdown]
# # Now, let's get the top 100 venues that are in  within a radius of 3000 meters.

# %% [markdown]
# ## Defining a Function to get list of neighborhood

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=3000
    LIMIT=100
     
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    #results = json_normalize(results)
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df1 = pd.DataFrame(venue_details,columns=column_names)
    return df1

# %% [markdown]
# ## Defining a function to get venue details like like count , rating , tip counts for a given venue id. This will be used for ranking.

# %%
def get_venue_details(venue_id):
    
   #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
           venue_id,
           CLIENT_ID, 
           CLIENT_SECRET, 
           VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df2 = pd.DataFrame(venue_details,columns=column_names)
    return df2

# %% [markdown]
# # Visualizing No. of Neighborhood in each Borough

# %%
plt.figure(figsize=(9,5), dpi=150)
# title
plt.title('Number of Neighborhood for each Borough in Toronto')
#On x-axis
plt.xlabel('Number of Neighborhood', fontsize = 10)
#On y-axis
plt.ylabel('Borough', fontsize=10)
#giving a bar plot
df_reqd_2.groupby('Borough')['Neighborhood'].count().sort_values().plot(kind='barh')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### North York has the maximum number of Neighborhood, followed by Downtown and Scarborough.

# %% [markdown]
# # Let us find out number of Indian Restaurants in Each Neighborhood.

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name']
indian_rest_toronto=pd.DataFrame(columns=column_names)
count=1
for row in df_reqd_2.values.tolist():
    Postcode, Borough, Neighborhood, Latitude, Longitude = row
    venues = get_venues(Latitude,Longitude)
    indian_resturants=venues[venues['Category']=='Indian Restaurant']   
    print('(',count,'/',len(df_reqd_2),')','Indian Resturants in '+Neighborhood+', '+Borough+':'+str(len(indian_resturants)))
    for resturant_detail in indian_resturants.values.tolist():
        id, name , category=resturant_detail
        indian_rest_toronto = indian_rest_toronto.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 102 ) Indian Resturants in Parkwoods, North York:1
# ( 2 / 102 ) Indian Resturants in Victoria Village, North York:2
# ( 3 / 102 ) Indian Resturants in Regent Park, Harbourfront, Downtown Toronto:0
# ( 4 / 102 ) Indian Resturants in Lawrence Manor, Lawrence Heights, North York:0
# ( 5 / 102 ) Indian Resturants in Queen's Park, Ontario Provincial Government, Downtown Toronto:1
# ( 6 / 102 ) Indian Resturants in Islington Avenue, Etobicoke:1
# ( 7 / 102 ) Indian Resturants in Malvern, Rouge, Scarborough:0
# ( 8 / 102 ) Indian Resturants in Don Mills, North York:0
# ( 9 / 102 ) Indian Resturants in Parkview Hill, Woodbine Gardens, East York:2
# ( 10 / 102 ) Indian Resturants in Garden District, Ryerson, Downtown Toronto:0
# ( 11 / 102 ) Indian Resturants in Glencairn, North York:0
# ( 12 / 102 ) Indian Resturants in West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale, Etobicoke:0
# ( 13 / 102 ) Indian Resturants in Rouge Hill, Port Union, Highland Creek, Scarborough:0
# ( 14 / 102 ) Indian Resturants in Don Mills, North York:2
# ( 15 / 102 ) Indian Resturants in Woodbine Heights, East York:6
# ( 16 / 102 ) Indian Resturants in St. James Town, Downtown Toronto:0
# ( 17 / 102 ) Indian Resturants in Humewood-Cedarvale, York:3
# ( 18 / 102 ) Indian Resturants in Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood, Etobicoke:1
# ( 19 / 102 ) Indian Resturants in Guildwood, Morningside, West Hill, Scarborough:0
# ( 20 / 102 ) Indian Resturants in The Beaches, East Toronto:3
# ( 21 / 102 ) Indian Resturants in Berczy Park, Downtown Toronto:0
# ( 22 / 102 ) Indian Resturants in Caledonia-Fairbanks, York:3
# ( 23 / 102 ) Indian Resturants in Woburn, Scarborough:3
# ( 24 / 102 ) Indian Resturants in Leaside, East York:3
# ( 25 / 102 ) Indian Resturants in Central Bay Street, Downtown Toronto:0
# ( 26 / 102 ) Indian Resturants in Christie, Downtown Toronto:1
# ( 27 / 102 ) Indian Resturants in Cedarbrae, Scarborough:4
# ( 28 / 102 ) Indian Resturants in Hillcrest Village, North York:0
# ( 29 / 102 ) Indian Resturants in Bathurst Manor, Wilson Heights, Downsview North, North York:1
# ( 30 / 102 ) Indian Resturants in Thorncliffe Park, East York:2
# ( 31 / 102 ) Indian Resturants in Richmond, Adelaide, King, Downtown Toronto:0
# ( 32 / 102 ) Indian Resturants in Dufferin, Dovercourt Village, West Toronto:4
# ( 33 / 102 ) Indian Resturants in Scarborough Village, Scarborough:2
# ( 34 / 102 ) Indian Resturants in Fairview, Henry Farm, Oriole, North York:0
# ( 35 / 102 ) Indian Resturants in Northwood Park, York University, North York:0
# ( 36 / 102 ) Indian Resturants in East Toronto, East York:1
# ( 37 / 102 ) Indian Resturants in Harbourfront East, Union Station, Toronto Islands, Downtown Toronto:0
# ( 38 / 102 ) Indian Resturants in Little Portugal, Trinity, West Toronto:0
# ( 39 / 102 ) Indian Resturants in Kennedy Park, Ionview, East Birchmount Park, Scarborough:0
# ( 40 / 102 ) Indian Resturants in Bayview Village, North York:0
# ( 41 / 102 ) Indian Resturants in Downsview, North York:0
# ( 42 / 102 ) Indian Resturants in The Danforth West, Riverdale, East Toronto:1
# ( 43 / 102 ) Indian Resturants in Toronto Dominion Centre, Design Exchange, Downtown Toronto:0
# ( 44 / 102 ) Indian Resturants in Brockton, Parkdale Village, Exhibition Place, West Toronto:1
# ( 45 / 102 ) Indian Resturants in Golden Mile, Clairlea, Oakridge, Scarborough:1
# ( 46 / 102 ) Indian Resturants in York Mills, Silver Hills, North York:1
# ( 47 / 102 ) Indian Resturants in Downsview, North York:0
# ( 48 / 102 ) Indian Resturants in India Bazaar, The Beaches West, East Toronto:2
# ( 49 / 102 ) Indian Resturants in Commerce Court, Victoria Hotel, Downtown Toronto:0
# ( 50 / 102 ) Indian Resturants in North Park, Maple Leaf Park, Upwood Park, North York:0
# ( 51 / 102 ) Indian Resturants in Humber Summit, North York:3
# ( 52 / 102 ) Indian Resturants in Cliffside, Cliffcrest, Scarborough Village West, Scarborough:1
# ( 53 / 102 ) Indian Resturants in Willowdale, Newtonbrook, North York:1
# ( 54 / 102 ) Indian Resturants in Downsview, North York:0
# ( 55 / 102 ) Indian Resturants in Studio District, East Toronto:1
# ( 56 / 102 ) Indian Resturants in Bedford Park, Lawrence Manor East, North York:1
# ( 57 / 102 ) Indian Resturants in Del Ray, Mount Dennis, Keelsdale and Silverthorn, York:1
# ( 58 / 102 ) Indian Resturants in Humberlea, Emery, North York:0
# ( 59 / 102 ) Indian Resturants in Birch Cliff, Cliffside West, Scarborough:1
# ( 60 / 102 ) Indian Resturants in Willowdale, North York:0
# ( 61 / 102 ) Indian Resturants in Downsview, North York:0
# ( 62 / 102 ) Indian Resturants in Lawrence Park, Central Toronto:2
# ( 63 / 102 ) Indian Resturants in Roselawn, Central Toronto:2
# ( 64 / 102 ) Indian Resturants in Runnymede, The Junction North, York:1
# ( 65 / 102 ) Indian Resturants in Weston, York:0
# ( 66 / 102 ) Indian Resturants in Dorset Park, Wexford Heights, Scarborough Town Centre, Scarborough:3
# ( 67 / 102 ) Indian Resturants in York Mills West, North York:1
# ( 68 / 102 ) Indian Resturants in Davisville North, Central Toronto:3
# ( 69 / 102 ) Indian Resturants in Forest Hill North & West, Central Toronto:4
# ( 70 / 102 ) Indian Resturants in High Park, The Junction South, West Toronto:1
# ( 71 / 102 ) Indian Resturants in Westmount, Etobicoke:0
# ( 72 / 102 ) Indian Resturants in Wexford, Maryvale, Scarborough:2
# ( 73 / 102 ) Indian Resturants in Willowdale, North York:0
# ( 74 / 102 ) Indian Resturants in North Toronto West, Central Toronto:3
# ( 75 / 102 ) Indian Resturants in The Annex, North Midtown, Yorkville, Central Toronto:1
# ( 76 / 102 ) Indian Resturants in Parkdale, Roncesvalles, West Toronto:3
# ( 77 / 102 ) Indian Resturants in Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens, Etobicoke:0
# ( 78 / 102 ) Indian Resturants in Agincourt, Scarborough:5
# ( 79 / 102 ) Indian Resturants in Davisville, Central Toronto:3
# ( 80 / 102 ) Indian Resturants in University of Toronto, Harbord, Downtown Toronto:0
# ( 81 / 102 ) Indian Resturants in Runnymede, Swansea, West Toronto:1
# ( 82 / 102 ) Indian Resturants in Clarks Corners, Tam O'Shanter, Sullivan, Scarborough:0
# ( 83 / 102 ) Indian Resturants in Moore Park, Summerhill East, Central Toronto:3
# ( 84 / 102 ) Indian Resturants in Kensington Market, Chinatown, Grange Park, Downtown Toronto:0
# ( 85 / 102 ) Indian Resturants in Milliken, Agincourt North, Steeles East, L'Amoreaux East, Scarborough:2
# ( 86 / 102 ) Indian Resturants in Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park, Central Toronto:3
# ( 87 / 102 ) Indian Resturants in CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport, Downtown Toronto:0
# ( 88 / 102 ) Indian Resturants in New Toronto, Mimico South, Humber Bay Shores, Etobicoke:2
# ( 89 / 102 ) Indian Resturants in South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens, Etobicoke:5
# ( 90 / 102 ) Indian Resturants in Steeles West, L'Amoreaux West, Scarborough:0
# ( 91 / 102 ) Indian Resturants in Rosedale, Downtown Toronto:1
# ( 92 / 102 ) Indian Resturants in Stn A PO Boxes, Downtown Toronto:0
# ( 93 / 102 ) Indian Resturants in Alderwood, Long Branch, Etobicoke:1
# ( 94 / 102 ) Indian Resturants in Northwest, Etobicoke:0
# ( 95 / 102 ) Indian Resturants in Upper Rouge, Scarborough:0
# ( 96 / 102 ) Indian Resturants in St. James Town, Cabbagetown, Downtown Toronto:0
# ( 97 / 102 ) Indian Resturants in First Canadian Place, Underground city, Downtown Toronto:0
# ( 98 / 102 ) Indian Resturants in The Kingsway, Montgomery Road, Old Mill North, Etobicoke:1
# ( 99 / 102 ) Indian Resturants in Church and Wellesley, Downtown Toronto:0
# ( 100 / 102 ) Indian Resturants in Business reply mail Processing Centre, East Toronto:2
# ( 101 / 102 ) Indian Resturants in Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East, Etobicoke:1
# ( 102 / 102 ) Indian Resturants in Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West, Etobicoke:1

# %% [markdown]
# ### How many Indian Restaurants did we get?
# ### Are there any null values?

# %%
print(indian_rest_toronto.shape)
print(indian_rest_toronto.isnull().sum())
indian_rest_toronto.head()
# Out:
# (118, 4)
# Borough         0
# Neighborhood    0
# ID              0
# Name            0
# dtype: int64
#             Borough                                 Neighborhood  \
# 0        North York                                    Parkwoods
# 1        North York                             Victoria Village
# 2        North York                             Victoria Village
# 3  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 4         Etobicoke                             Islington Avenue
#
#                          ID                          Name
# 0  4c27cddd9fb5d13a8cab9857             Patna Kebab House
# 1  4b9bccbef964a520ae2636e3             Sultan Of Samosas
# 2  4c27cddd9fb5d13a8cab9857             Patna Kebab House
# 3  4c8c21fdf0ce236ab28e15ef        Butter Chicken Factory
# 4  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine

# %% [markdown]
# ### We have got 118 Indian Restaurants!

# %% [markdown]
# # Let us look Indian Restaurants in each Borough

# %%
plt.figure(figsize=(9,5), dpi = 150)
# title
plt.title('Number of Indian Resturants for each Borough in Toronto')
#On x-axis
plt.xlabel('Number of Indian Resturants', fontsize = 10)
#On y-axis
plt.ylabel('Borough', fontsize=10)
#giving a bar plot
indian_rest_toronto.groupby('Borough')['ID'].count().sort_values().plot(kind='barh',color='Green')
#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### Scarborough and Central Toronto has the maximum number of Indian Restaurants, while Downtown has the least.
# ### Intersting! Lets dig more!!

# %% [markdown]
# ### Which Neighborhood has the highest number of Indian Restaurants?

# %%
plt.figure(figsize=(9,5), dpi = 150)
# title
plt.title('Number of Indian Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('No.of Indian Resturants', fontsize = 15)
#On y-axis
plt.ylabel('Neighborhood', fontsize=15)
#giving a bar plot
#indian_rest_toronto.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='barh', color='y')
indian_rest_toronto.groupby(['Neighborhood','Borough'])['ID'].count().nlargest(9).plot(kind='barh', color='y')


#legend
plt.legend()
#displays the plot
plt.show()

# %% [markdown]
# ### We can see that Woodbine, East York has the highest number of Indian Restaurants than any other Borough of Toronto.

# %% [markdown]
# ### Lets find out the Indian Restaurants in East York.

# %%
rest_list_east=indian_rest_toronto[indian_rest_toronto['Borough']=='East York']
rest_list_east
# Out:
#       Borough                     Neighborhood                        ID  \
# 5   East York  Parkview Hill, Woodbine Gardens  4b9bccbef964a520ae2636e3
# 6   East York  Parkview Hill, Woodbine Gardens  507a19e5e4b0602b62f73d11
# 9   East York                 Woodbine Heights  4ae0c7a8f964a520638221e3
# 10  East York                 Woodbine Heights  4b9bccbef964a520ae2636e3
# 11  East York                 Woodbine Heights  4afc9816f964a520312422e3
# 12  East York                 Woodbine Heights  4daf08e66e81e2dffdd4fe40
# 13  East York                 Woodbine Heights  4bac30a2f964a52018ea3ae3
# 14  East York                 Woodbine Heights  507a19e5e4b0602b62f73d11
# 28  East York                          Leaside  4b75c28af964a520ba222ee3
# 29  East York                          Leaside  4daf08e66e81e2dffdd4fe40
# 30  East York                          Leaside  5169d445e4b07de190b5c3d6
# 37  East York                 Thorncliffe Park  4daf08e66e81e2dffdd4fe40
# 38  East York                 Thorncliffe Park  4b75c28af964a520ba222ee3
# 45  East York                     East Toronto  4ae0c7a8f964a520638221e3
#
#                           Name
# 5            Sultan Of Samosas
# 6             Faley Restaurant
# 9                 Udupi Palace
# 10           Sultan Of Samosas
# 11                   Motimahal
# 12  Iqbal Kebab & Sweet Centre
# 13            Bombay Chowpatty
# 14            Faley Restaurant
# 28                   Kamasutra
# 29  Iqbal Kebab & Sweet Centre
# 30      Marigold Indian Bistro
# 37  Iqbal Kebab & Sweet Centre
# 38                   Kamasutra
# 45                Udupi Palace

# %% [markdown]
# ## Now let us get the Ranking of Each Restaurant based on Likes, Ratings, Tips from the FourSquare API.

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
indian_rest_stats_toronto=pd.DataFrame(columns=column_names)
count=1


for row in indian_rest_toronto.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(indian_rest_toronto),')','processed')
    indian_rest_stats_toronto = indian_rest_stats_toronto.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.0     6
# ( 1 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.6    24
# ( 2 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.0     6
# ( 3 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4c8c21fdf0ce236ab28e15ef  Butter Chicken Factory     18     8.4    10
# ( 4 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine      5     6.9    10
# ( 5 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.6    24
# ( 6 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  507a19e5e4b0602b62f73d11  Faley Restaurant      6     6.7     4
# ( 7 / 118 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     7.6     6
# ( 8 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  507a19e5e4b0602b62f73d11  Faley Restaurant      6     6.7     4
# ( 9 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 10 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.6    24
# ( 11 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     25     7.7    13
# ( 12 / 118 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     7.6     6
# ( 13 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  4bac30a2f964a52018ea3ae3  Bombay Chowpatty      7     7.2     5
# ( 14 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  507a19e5e4b0602b62f73d11  Faley Restaurant      6     6.7     4
# ( 15 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 16 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     40     8.8    19
# ( 17 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4ae09642f964a520a68021e3  Savera Indian Cuisine      2     7.5     6
# ( 18 / 118 ) processed
#                          ID                                 Name  Likes  \
# 0  5809314638faf998ad00761d  Chaska Indian Street Food Obsession     10
#
#    Rating  Tips
# 0     7.0     9
# ( 19 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 20 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4dcd7c6352b1f8915b7e7f7e  Delhi Bistro      6     7.0     3
# ( 21 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     25     7.7    13
# ( 22 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 23 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 24 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4ae09642f964a520a68021e3  Savera Indian Cuisine      2     7.5     6
# ( 25 / 118 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.4     3
# ( 26 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     22     8.0     8
# ( 27 / 118 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     12     6.8    12
# ( 28 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 29 / 118 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     7.6     6
# ( 30 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 31 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 32 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     22     8.0     8
# ( 33 / 118 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.4     3
# ( 34 / 118 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     12     6.8    12
# ( 35 / 118 ) processed
#                          ID                                Name  Likes  \
# 0  4d570727fb65236a7f600db4  Silver Spoon Pak-Indian Restaurant     11
#
#    Rating  Tips
# 0     7.3     6
# ( 36 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.4    15
# ( 37 / 118 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4daf08e66e81e2dffdd4fe40  Iqbal Kebab & Sweet Centre     13     7.6     6
# ( 38 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 39 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 40 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4adb969ef964a520332921e3  Banjara Indian Cuisine    142     8.8    75
# ( 41 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 42 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     40     8.8    19
# ( 43 / 118 ) processed
#                          ID                                      Name  Likes  \
# 0  4b6dbc8ef964a520fd8a2ce3  Anjappar Authentic Chettinadu Restaurant     21
#
#    Rating  Tips
# 0     8.2    10
# ( 44 / 118 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bd48a734e32d13a4254bf80  Govardhan Thal      7     7.4     3
# ( 45 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 46 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 47 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4aecbbb0f964a520bcca21e3  Mother India     45     8.0    31
# ( 48 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4b9bccbef964a520ae2636e3  Sultan Of Samosas     29     8.6    24
# ( 49 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  5c6816acb3d8e2002c7b6383  Goa Kitchen      5     7.1     2
# ( 50 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 51 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     25     7.7    13
# ( 52 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.7     6
# ( 53 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4cead0ed9f776ea8bdcd6a22  Madras Dosa Hut      7     6.7     1
# ( 54 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4bca0625511f9521a6d0aec7  Brar Pakwan      4     6.3     2
# ( 55 / 118 ) processed
#                          ID                                      Name  Likes  \
# 0  4b6dbc8ef964a520fd8a2ce3  Anjappar Authentic Chettinadu Restaurant     21
#
#    Rating  Tips
# 0     8.2    10
# ( 56 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  51dde446498e8598c097f3d6  The Indian Cuisine      5     6.1     2
# ( 57 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 58 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.4    15
# ( 59 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 60 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4dcd7c6352b1f8915b7e7f7e  Delhi Bistro      6     7.0     3
# ( 61 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 62 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 63 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 64 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.4    15
# ( 65 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 66 / 118 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.2     6
# ( 67 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.0     6
# ( 68 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     22     8.0     8
# ( 69 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.4    15
# ( 70 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 71 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 72 / 118 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  4c51e0069d642d7f4aef50de  Eat Indian By Amaya      7     7.2     7
# ( 73 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 74 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 75 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     40     8.8    19
# ( 76 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4ae09642f964a520a68021e3  Savera Indian Cuisine      2     7.5     6
# ( 77 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 78 / 118 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857  Patna Kebab House      4     8.0     6
# ( 79 / 118 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5226562611d2cd49d83ef03b  Kairali      9     7.2     6
# ( 80 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 81 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 82 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4d796616542ab1f75eb87c41  The Copper Chimney     14     7.4    15
# ( 83 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 84 / 118 ) processed
#                          ID                     Name  Likes  Rating  Tips
# 0  4adca78af964a520592e21e3  South Indian Dosa Mahal     28     7.8    15
# ( 85 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4aecbbb0f964a520bcca21e3  Mother India     45     8.0    31
# ( 86 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 87 / 118 ) processed
#                          ID                                Name  Likes  \
# 0  4d570727fb65236a7f600db4  Silver Spoon Pak-Indian Restaurant     11
#
#    Rating  Tips
# 0     7.3     6
# ( 88 / 118 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     28
#
#    Rating  Tips
# 0     7.6    14
# ( 89 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4d6008f829ef236a8832a059  CANBE Foods Inc     22     8.0     8
# ( 90 / 118 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4aee2557f964a52080d221e3  Samosa King - Embassy Restaurant     36     7.2
#
#    Tips
# 0    25
# ( 91 / 118 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4c77fc87bd346dcb8c90f0ef  La Sani Grill     12     6.8    12
# ( 92 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 93 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 94 / 118 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  4c51e0069d642d7f4aef50de  Eat Indian By Amaya      7     7.2     7
# ( 95 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4b511f6ff964a520994327e3  Curry Twist     20     8.3    17
# ( 96 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 97 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4b75c28af964a520ba222ee3  Kamasutra     18     8.1    12
# ( 98 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     40     8.8    19
# ( 99 / 118 ) processed
#                          ID                                      Name  Likes  \
# 0  4b93d4a7f964a520eb5334e3  Saravanaa Bhavan South Indian Restaurant     28
#
#    Rating  Tips
# 0     7.6    14
# ( 100 / 118 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4aee2557f964a52080d221e3  Samosa King - Embassy Restaurant     36     7.2
#
#    Tips
# 0    25
# ( 101 / 118 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4c62c59ce1621b8dd0332453  Roti Cuisine of India     40     8.8    19
# ( 102 / 118 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  52418b0b7e48222eea81d2d2  Pukka Restaurant     41     9.0    26
# ( 103 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  5169d445e4b07de190b5c3d6  Marigold Indian Bistro     11     8.1    11
# ( 104 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  5557eeff498ea920bf32ab39  Tich - Modern Indian Cuisine     32     8.4     8
# ( 105 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4bc10d44abf49521d773c093  Bombay on the Lake      6     7.2     9
# ( 106 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4c8baba11797236a141c6d88  Samosa & Sweet Factory     19     7.8     9
# ( 107 / 118 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4af45ad0f964a5209bf121e3  Tandoori Time      2     6.7     5
# ( 108 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4b8f4165f964a5205f4f33e3  Rajdhani Sweets & Restaurant      3     6.7     6
# ( 109 / 118 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4cead0ed9f776ea8bdcd6a22  Madras Dosa Hut      7     6.7     1
# ( 110 / 118 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4bca0625511f9521a6d0aec7  Brar Pakwan      4     6.3     2
# ( 111 / 118 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4c8c21fdf0ce236ab28e15ef  Butter Chicken Factory     18     8.4    10
# ( 112 / 118 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4bc10d44abf49521d773c093  Bombay on the Lake      6     7.2     9
# ( 113 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine      5     6.9    10
# ( 114 / 118 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4ae0c7a8f964a520638221e3  Udupi Palace     79     8.4    31
# ( 115 / 118 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4afc9816f964a520312422e3  Motimahal     25     7.7    13
# ( 116 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  5557eeff498ea920bf32ab39  Tich - Modern Indian Cuisine     32     8.4     8
# ( 117 / 118 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  5557eeff498ea920bf32ab39  Tich - Modern Indian Cuisine     32     8.4     8
# ( 118 / 118 ) processed

# %% [markdown]
# ## We have got the data of Likes, Rating and Tips for each Indian Restaurant in Toronto, Canada.

# %% [markdown]
# ### Let's move forward and see our data.

# %%
print('DataFrame has :',indian_rest_stats_toronto.shape[0],'rows and', indian_rest_stats_toronto.shape[1],'columns')
indian_rest_stats_toronto.head()
# Out:
# DataFrame has : 118 rows and 7 columns
#             Borough                                 Neighborhood  \
# 0        North York                                    Parkwoods
# 1        North York                             Victoria Village
# 2        North York                             Victoria Village
# 3  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 4         Etobicoke                             Islington Avenue
#
#                          ID                          Name Likes  Rating Tips
# 0  4c27cddd9fb5d13a8cab9857             Patna Kebab House     4     8.0    6
# 1  4b9bccbef964a520ae2636e3             Sultan Of Samosas    29     8.6   24
# 2  4c27cddd9fb5d13a8cab9857             Patna Kebab House     4     8.0    6
# 3  4c8c21fdf0ce236ab28e15ef        Butter Chicken Factory    18     8.4   10
# 4  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine     5     6.9   10

# %% [markdown]
# ## As we are using FourSquare API to fetch the details of each Indian Restaurants, it comes under Premium Call and has a Limit of 500 Calls/Day.
# ## So, let us save the DataFrame to a CSV File, and from here on we will use the CSV file for further manipulations.

# %%
indian_rest_stats_toronto.to_csv('indian_rest_stats_toronto.csv', index=False)
print('File Saved in your directory as indian_rest_stats_toronto.csv')
# Out:
# File Saved in your directory as indian_rest_stats_toronto.csv

# %% [markdown]
# ## Loading the file.

# %%
indian_rest_stats_toronto_csv=pd.read_csv('indian_rest_stats_toronto.csv')
indian_rest_stats_toronto_csv.head()
# Out:
#             Borough                                 Neighborhood  \
# 0        North York                                    Parkwoods
# 1        North York                             Victoria Village
# 2        North York                             Victoria Village
# 3  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 4         Etobicoke                             Islington Avenue
#
#                          ID                          Name  Likes  Rating  Tips
# 0  4c27cddd9fb5d13a8cab9857             Patna Kebab House      4     8.0     6
# 1  4b9bccbef964a520ae2636e3             Sultan Of Samosas     29     8.6    24
# 2  4c27cddd9fb5d13a8cab9857             Patna Kebab House      4     8.0     6
# 3  4c8c21fdf0ce236ab28e15ef        Butter Chicken Factory     18     8.4    10
# 4  4af1c64ff964a5200ae321e3  Chutneys Fine Indian Cuisine      5     6.9    10

# %% [markdown]
# ## Check the type of varaibles and null values.

# %%
print(indian_rest_stats_toronto_csv.info())
print(indian_rest_stats_toronto_csv.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 7 columns):
# Borough         118 non-null object
# Neighborhood    118 non-null object
# ID              118 non-null object
# Name            118 non-null object
# Likes           118 non-null int64
# Rating          118 non-null float64
# Tips            118 non-null int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 6.6+ KB
# None
# Borough         0
# Neighborhood    0
# ID              0
# Name            0
# Likes           0
# Rating          0
# Tips            0
# dtype: int64

# %% [markdown]
# ### Data types are correct and as per requirement for further analysis.

# %% [markdown]
# ## Indian Restaurants based on MAX Likes.

# %%
print(indian_rest_stats_toronto_csv.iloc[indian_rest_stats_toronto_csv['Likes'].idxmax()])
# Out:
# Borough                         West Toronto
# Neighborhood    Dufferin, Dovercourt Village
# ID                  4adb969ef964a520332921e3
# Name                  Banjara Indian Cuisine
# Likes                                    142
# Rating                                   8.8
# Tips                                      75
# Name: 40, dtype: object

# %% [markdown]
# ## Indian Restaurants based on Highest Ratings.

# %%
print(indian_rest_stats_toronto_csv.iloc[indian_rest_stats_toronto_csv['Rating'].idxmax()])
# Out:
# Borough                             York
# Neighborhood          Humewood-Cedarvale
# ID              52418b0b7e48222eea81d2d2
# Name                    Pukka Restaurant
# Likes                                 41
# Rating                                 9
# Tips                                  26
# Name: 15, dtype: object

# %% [markdown]
# ## Indian Restaurants based on MAX Tips.

# %%
print(indian_rest_stats_toronto_csv.iloc[indian_rest_stats_toronto_csv['Tips'].idxmax()])
# Out:
# Borough                         West Toronto
# Neighborhood    Dufferin, Dovercourt Village
# ID                  4adb969ef964a520332921e3
# Name                  Banjara Indian Cuisine
# Likes                                    142
# Rating                                   8.8
# Tips                                      75
# Name: 40, dtype: object

# %% [markdown]
# ## Top Borough for Indian Restaurants based on Average Ratings.

# %%
toronto_borough_stats=indian_rest_stats_toronto_csv.groupby('Borough')['Rating'].mean().reset_index()
toronto_borough_stats.columns=['Borough','Average Rating']
toronto_borough_stats.nlargest(10,'Average Rating')
# Out:
#             Borough  Average Rating
# 1  Downtown Toronto        8.600000
# 7      West Toronto        8.360000
# 8              York        8.337500
# 0   Central Toronto        8.141667
# 2      East Toronto        8.011111
# 3         East York        7.814286
# 6       Scarborough        7.550000
# 4         Etobicoke        7.276923
# 5        North York        7.230769

# %% [markdown]
# ### We can see that DownTown Toronto has the Best Indian Restaurants based on Average Ratings.

# %% [markdown]
# ## Visualizing The Best of Borough.

# %%
toronto_borough_stats=toronto_borough_stats.sort_values(by='Average Rating')
sns.set(style="darkgrid",font_scale=2,rc={'figure.figsize':(15,6)})
ax = sns.barplot(x="Borough", y="Average Rating", data=toronto_borough_stats, palette="prism_r")
plt.title('Average Rating of Indian Restaurants in Each Borough')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Top Neighborhoods for Indian Restaurants based on Average Ratings.

# %%
toronto_neighborhood_stats=indian_rest_stats_toronto_csv.groupby(['Neighborhood'])['Rating'].mean().reset_index()
toronto_neighborhood_stats.columns=['Neighborhood','Average Rating']
toronto_neighborhood_stats.sort_values(by='Average Rating',ascending=False).head()
# Out:
#                                          Neighborhood  Average Rating
# 9                                            Christie        9.000000
# 46                The Annex, North Midtown, Yorkville        9.000000
# 16                       Dufferin, Dovercourt Village        8.725000
# 45  Summerhill West, Rathnelly, South Hill, Forest...        8.633333
# 20                    Golden Mile, Clairlea, Oakridge        8.600000

# %% [markdown]
# ### We can see that Christie and The Annex has the Best Indian Restaurants based on Average Ratings.

# %% [markdown]
# ## Visualizing The Best of Neighborhoods.
# ### Based on ratings above 8.0

# %%
avg_rating=8.0
best_toronto_neighborhood_stats=toronto_neighborhood_stats[toronto_neighborhood_stats['Average Rating']>=avg_rating]
print(best_toronto_neighborhood_stats.shape[0],'Indian Restaurants has average rating of', avg_rating, 'and above. \n Check the list below.')
best_toronto_neighborhood_stats.sort_values(by='Average Rating',ascending=False)
# Out:
# 28 Indian Restaurants has average rating of 8.0 and above.
#  Check the list below.
#                                          Neighborhood  Average Rating
# 9                                            Christie        9.000000
# 46                The Annex, North Midtown, Yorkville        9.000000
# 16                       Dufferin, Dovercourt Village        8.725000
# 45  Summerhill West, Rathnelly, South Hill, Forest...        8.633333
# 20                    Golden Mile, Clairlea, Oakridge        8.600000
# 23                                 Humewood-Cedarvale        8.433333
# 29  Mimico NW, The Queensway West, South of Bloor,...        8.400000
# 38                                           Rosedale        8.400000
# 44                                    Studio District        8.400000
# 33  Old Mill South, King's Mill Park, Sunnylea, Hu...        8.400000
# 37        Queen's Park, Ontario Provincial Government        8.400000
# 17                                       East Toronto        8.400000
# 48                       The Danforth West, Riverdale        8.400000
# 19                           Forest Hill North & West        8.350000
# 30                        Moore Park, Summerhill East        8.333333
# 41                      Runnymede, The Junction North        8.300000
# 40                                 Runnymede, Swansea        8.300000
# 51                                   Victoria Village        8.300000
# 21                      High Park, The Junction South        8.300000
# 13   Del Ray, Mount Dennis, Keelsdale and Silverthorn        8.300000
# 7                                 Caledonia-Fairbanks        8.266667
# 10    Cliffside, Cliffcrest, Scarborough Village West        8.200000
# 26                                      Lawrence Park        8.100000
# 6               Business reply mail Processing Centre        8.050000
# 24                     India Bazaar, The Beaches West        8.050000
# 34                             Parkdale, Roncesvalles        8.033333
# 36                                          Parkwoods        8.000000
# 5        Brockton, Parkdale Village, Exhibition Place        8.000000

# %% [markdown]
# ## Merging DataFrame to get the Coordinates.

# %%
best_neighborhood_folium=pd.merge(best_toronto_neighborhood_stats,df_reqd_2,how='inner',on='Neighborhood')
best_neighborhood_folium=best_neighborhood_folium.rename(columns={'Borough_x':'Borough'})
best_neighborhood_folium=best_neighborhood_folium[['Borough','Neighborhood','Average Rating','Latitude','Longitude']]
print('We have our required DatFrame ready to be plotted on a Map.')
best_neighborhood_folium=best_neighborhood_folium.sort_values(by='Average Rating', ascending=False).reset_index(drop=True)
best_neighborhood_folium['Average Rating']=best_neighborhood_folium['Average Rating'].round(2)# set precision to 2 decimal place
best_neighborhood_folium
# Out:
# We have our required DatFrame ready to be plotted on a Map.
#              Borough                                       Neighborhood  \
# 0   Downtown Toronto                                           Christie
# 1    Central Toronto                The Annex, North Midtown, Yorkville
# 2       West Toronto                       Dufferin, Dovercourt Village
# 3    Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 4        Scarborough                    Golden Mile, Clairlea, Oakridge
# 5               York                                 Humewood-Cedarvale
# 6          Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 7   Downtown Toronto                                           Rosedale
# 8       East Toronto                                    Studio District
# 9          Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 10  Downtown Toronto        Queen's Park, Ontario Provincial Government
# 11         East York                                       East Toronto
# 12      East Toronto                       The Danforth West, Riverdale
# 13   Central Toronto                           Forest Hill North & West
# 14   Central Toronto                        Moore Park, Summerhill East
# 15              York                      Runnymede, The Junction North
# 16      West Toronto                                 Runnymede, Swansea
# 17        North York                                   Victoria Village
# 18      West Toronto                      High Park, The Junction South
# 19              York   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 20              York                                Caledonia-Fairbanks
# 21       Scarborough    Cliffside, Cliffcrest, Scarborough Village West
# 22   Central Toronto                                      Lawrence Park
# 23      East Toronto              Business reply mail Processing Centre
# 24      East Toronto                     India Bazaar, The Beaches West
# 25      West Toronto                             Parkdale, Roncesvalles
# 26        North York                                          Parkwoods
# 27      West Toronto       Brockton, Parkdale Village, Exhibition Place
#
#     Average Rating   Latitude  Longitude
# 0             9.00  43.669542 -79.422564
# 1             9.00  43.672710 -79.405678
# 2             8.73  43.669005 -79.442259
# 3             8.63  43.686412 -79.400049
# 4             8.60  43.711112 -79.284577
# 5             8.43  43.693781 -79.428191
# 6             8.40  43.628841 -79.520999
# 7             8.40  43.679563 -79.377529
# 8             8.40  43.659526 -79.340923
# 9             8.40  43.636258 -79.498509
# 10            8.40  43.662301 -79.389494
# 11            8.40  43.685347 -79.338106
# 12            8.40  43.679557 -79.352188
# 13            8.35  43.696948 -79.411307
# 14            8.33  43.689574 -79.383160
# 15            8.30  43.673185 -79.487262
# 16            8.30  43.651571 -79.484450
# 17            8.30  43.725882 -79.315572
# 18            8.30  43.661608 -79.464763
# 19            8.30  43.691116 -79.476013
# 20            8.27  43.689026 -79.453512
# 21            8.20  43.716316 -79.239476
# 22            8.10  43.728020 -79.388790
# 23            8.05  43.662744 -79.321558
# 24            8.05  43.668999 -79.315572
# 25            8.03  43.648960 -79.456325
# 26            8.00  43.753259 -79.329656
# 27            8.00  43.636847 -79.428191

# %% [markdown]
# ## Visualizing The Best of Neighborhoods based on Average Rating of 8.0 and above on Map.

# %%
best_neighborhood_avg_rating_map_2 = folium.Map(location=geo_location('Toronto'), zoom_start=10, tiles='https://api.mapbox.com/styles/v1/explorer020/cka9yy2dn14l51iptugr1shzf/tiles/256/{z}/{x}/{y}@2x?access_token=pk.eyJ1IjoiZXhwbG9yZXIwMjAiLCJhIjoiY2thOXhvYjdyMHJoYzJycDRlbmw3YTg3ZiJ9.T9QjJc87oYLSknnlBH21Tg',attr='XXX Mapbox Attribution')

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(best_neighborhood_avg_rating_map_2)

for lat, lng, rating, neighborhood in zip(best_neighborhood_folium['Latitude'], best_neighborhood_folium['Longitude'],best_neighborhood_folium['Average Rating'],best_neighborhood_folium['Neighborhood']):
    label = '{},{}'.format(rating,neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        [lat, lng],
        popup=label).add_to(incidents)  
best_neighborhood_avg_rating_map_2.save('best_neighborhood_avg_rating_map_2.html')
best_neighborhood_avg_rating_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Conclusion
#
# - What is best location in Toronto for Indian Cuisine?
#   - Banjara Indian Cuisine, Dufferin, West Toronto has the best Indian food.
# - Which areas have potential Indian Restaurant Market?
#   - North York, Etobicoke has the least rated Indian restaurants.
#   - For an investor, it&#39;s an opportunity to grab to come up with high quality restaurant.
# - Which all areas lack Indian Restaurants?
#   - Downtown has the lowest number of Indian Restaurants but are highly rated.
#   - For an investor, to come up with variety and quality is a challenge to conquer.
# - Which is the best place to stay if I prefer Indian Cuisine?
#   - West and Central Toronto are the places where one should stay if they prefer Indian Cuisine. These areas have quality and variety both.
#
# # Limitation
#
# - Food habits and likings are completely relative.
# - Ranking of Borough, Neighborhood and Restaurants are based on ratings data fetched from FourSquare API.
# - Results may vary if more data is available.

# %% [markdown]
# # Thank You

# %% [markdown]
# # Aayush Verma
